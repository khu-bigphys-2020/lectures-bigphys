# %% [markdown]
# <a href="https://colab.research.google.com/github/dustyattenborough/lectures-bigphys/blob/master/spring01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 빅데이터 물리학 첫번째 예제
#
# 이 노트북은 빅데이터 물리학 예제입니다. 파이선기초를 하겠습니다.

# %%
#빅데이터 물리학 첫번쨰 예제

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import time
from google.colab import files
import os
import torch
from math import *

# %%
x = torch.randn(3,5)

print(x)
# Out:
# tensor([[ 0.8114,  0.3012, -0.6952, -1.4169, -1.1106],
#         [ 0.1672,  0.1858,  0.2736, -0.2251,  1.8881],
#         [ 0.1023,  1.2755, -0.6953,  0.2699,  0.9411]])

# %%
def SHOforce(x,k,startingP):
  return -k*(x-startingP)

# %%
mass1 = 1
k1 = 1
startP=10
x1 = [startP+3]
v1 = [0]
vhf1=[]
a1 = [0]
m1=1 # this is mass of particle
dt = 0.001
t=0.0
v=1.0
x=0.0
m=1
a=0
time1=[0]
Phi=math.pi

for i in range(100000):
  a1.append(SHOforce(x1[i],k1,startP)/m1-0.1*v1[i])
  vhf1.append(v1[i]+a1[i]*(dt/2))
  x1.append(x1[i]+vhf1[i]*dt)
  v1.append(vhf1[i]+a1[i+1]*(dt/2))
  time1.append(time1[i]+dt)
  


figure=plt.figure(figsize=(5,5))
plt.plot(x1,v1,"-")
plt.xlabel('time')
plt.ylabel('x1')
plt.grid(True)

plt.title("sho")
# Out:
# Text(0.5, 1.0, 'sho')

# %%
x=x+v*dt
v=v+a*dt

print(x,v)
# Out:
# 0.01 1.0

# %%
def SHOforce(x,k):
  return -k*x

# %%
# Out:
# Text(0.5, 1.0, 'sho')

# %%
# Out:
# Text(0.5, 1.0, 'sho')

# %%
2*acos(0)
# Out:
# 3.141592653589793

# %%
print(1,2,3, sep = " : ",end="  endofline")
# Out:
# 1 : 2 : 3  endofline

# %%
if __name__=='__main__':
  print("this is main")
# Out:
# this is main
