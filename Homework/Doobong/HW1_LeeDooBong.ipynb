# %% [markdown]
# <a href="https://colab.research.google.com/github/Doobong/lectures-bigphys/blob/master/HW1_LeeDooBong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from math import *

# %%
m = 1 
k = 0.1
t = 0.0
dt = 0.1

v_0 = 0.0 
v_1 = 0.0 
v_2 = 0.0 
v_3 = 0.0 
v_4 = 0.0 
v_5 = 0.0 
v_6 = 0.0 
v_7 = 0.0 
v_8 = 0.0 
v_9 = 0.0 
v_10 = 0.0

x_0 = 0.0
x_1 = 1.0
x_2 = 2.0
x_3 = 3.0
x_4 = 4.0 + 0.3
x_5 = 5.0
x_6 = 6.0
x_7 = 7.0
x_8 = 8.0
x_9 = 9.0
x_10 = 10.0
x_11 = 11.0

# %%
t_list = [t,]

x_1list = [x_1,]
x_2list = [x_2,]
x_3list = [x_3,]
x_4list = [x_4,]
x_5list = [x_5,]
x_6list = [x_6,]
x_7list = [x_7,]
x_8list = [x_8,]
x_9list = [x_9,]
x_10list = [x_10,]

v_1list = [v_1,]
v_2list = [v_2,]
v_3list = [v_3,]
v_4list = [v_4,]
v_5list = [v_5,]
v_6list = [v_6,]
v_7list = [v_7,]
v_8list = [v_8,]
v_9list = [v_9,]
v_10list = [v_10,]

# %%
for i in range(10000):    
    t = t + dt

    x_1 = x_1 + v_1*dt
    x_2 = x_2 + v_2*dt
    x_3 = x_3 + v_3*dt
    x_4 = x_4 + v_4*dt
    x_5 = x_5 + v_5*dt
    x_6 = x_6 + v_6*dt
    x_7 = x_7 + v_7*dt
    x_8 = x_8 + v_8*dt
    x_9 = x_9 + v_9*dt
    x_10 = x_10 + v_10*dt


    a_1 = (-k*(x_1 - x_0) + k*(x_2 - x_1))/m
    a_2 = (-k*(x_2 - x_1) + k*(x_3 - x_2))/m
    a_3 = (-k*(x_3 - x_2) + k*(x_4 - x_3))/m
    a_4 = (-k*(x_4 - x_3) + k*(x_5 - x_4))/m
    a_5 = (-k*(x_5 - x_4) + k*(x_6 - x_5))/m
    a_6 = (-k*(x_6 - x_5) + k*(x_7 - x_6))/m
    a_7 = (-k*(x_7 - x_6) + k*(x_8 - x_7))/m
    a_8 = (-k*(x_8 - x_7) + k*(x_9 - x_8))/m
    a_9 = (-k*(x_9 - x_8) + k*(x_10 - x_9))/m
    a_10 = (-k*(x_10 - x_9) + k*(x_11 - x_10))/m


    v_1 = v_1 + a_1*dt
    v_2 = v_2 + a_2*dt
    v_3 = v_3 + a_3*dt
    v_4 = v_4 + a_4*dt
    v_5 = v_5 + a_5*dt
    v_6 = v_6 + a_6*dt
    v_7 = v_7 + a_7*dt
    v_8 = v_8 + a_8*dt
    v_9 = v_9 + a_9*dt
    v_10 = v_10 + a_10*dt


    t_list.append(t)
    x_1list.append(x_1)
    x_2list.append(x_2)
    x_3list.append(x_3)
    x_4list.append(x_4)
    x_5list.append(x_5)
    x_6list.append(x_6)
    x_7list.append(x_7)
    x_8list.append(x_8)
    x_9list.append(x_9)
    x_10list.append(x_10)


    v_1list.append(v_1)
    v_2list.append(v_2)
    v_3list.append(v_3)
    v_4list.append(v_4)
    v_5list.append(v_5)
    v_6list.append(v_6)
    v_7list.append(v_7)
    v_8list.append(v_8)
    v_9list.append(v_9)
    v_10list.append(v_10)

# %%
plt.plot(t_list, x_1list)
plt.plot(t_list, x_2list)
plt.plot(t_list, x_3list)
plt.plot(t_list, x_4list)
plt.plot(t_list, x_5list)
plt.plot(t_list, x_6list)
plt.plot(t_list, x_7list)
plt.plot(t_list, x_8list)
plt.plot(t_list, x_9list)
plt.plot(t_list, x_10list)
plt.show
# Out:
# <function matplotlib.pyplot.show>
