# %% [markdown]
# <a href="https://colab.research.google.com/github/parkseastar/lectures-bigphys/blob/master/HSPark_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
row = 20
column = 20
N = 300

null_data = np.zeros((row, column))

df = pd.DataFrame(null_data)
df.loc[0] = [10 for _ in range(column)]

for _ in tqdm(range(N)):
    for i in range(1, row - 1):
        for j in range(1, column - 1):
            k = (df.loc[i + 1, j] + df.loc[i - 1, j] + df.loc[i, j + 1] + df.loc[i, j - 1])/4
            df.loc[i, j] = k

df.head()
# Out:
# 100%|██████████| 300/300 [00:33<00:00,  9.02it/s]
#      0          1          2          3   ...         16         17         18    19
# 0  10.0  10.000000  10.000000  10.000000  ...  10.000000  10.000000  10.000000  10.0
# 1   0.0   4.969552   6.915106   7.812628  ...   7.812643   6.915118   4.969559   0.0
# 2   0.0   2.963106   4.878249   6.047628  ...   6.047657   4.878272   2.963119   0.0
# 3   0.0   2.004628   3.587168   4.726345  ...   4.726388   3.587202   2.004647   0.0
# 4   0.0   1.468246   2.739464   3.749410  ...   3.749464   2.739506   1.468270   0.0
#
# [5 rows x 20 columns]

# %%
cm = sns.light_palette("green", as_cmap=True)

s = df.style.background_gradient(cmap=cm)
s.to_excel("data.xlsx")
s
# Out:
# <style  type="text/css" >
#     #T_34f44e66_fe5f_11ea_a710_0242ac1c0002row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_34f44e66_fe5f_11ea_a710_0242ac1c0002row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_34f44e66_fe5f_11ea_a710_0242ac1c0002row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_34f44e66_fe5f_11ea_a710_0242ac1c0002row0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_34f44e66_fe5f_11ea_a710_0242ac1c0002row0_col4 {
#             background-color:  #008000;
# ...
